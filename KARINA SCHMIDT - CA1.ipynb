# %% [markdown]
# # KARINA FRANCIELI SCHMIDT - 2023314
#
# ## Machine learning for business
#
# ### Lecturer: Dr. Muhammad Iqbal

# %% [markdown]
#  Imports libraries and modules needed to analyse data below

# %%
# %matplotlib inline 
import numpy as np 
from sklearn.decomposition import PCA
import seaborn as sns; 
import matplotlib.pyplot as plt
import pandas as pd
import math

from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Loading and naming dataset from CVS, which will make it ready for the analyses that will be done.

# %%
df = pd.read_csv("education.csv")

# %% [markdown]
# By calling df.head(), you will see a representation of the first few rows of the dataframe, which is useful for a quick initial inspection of the data and for understanding its structure. This can help you to check that the data has been loaded correctly and to get an idea of the types of data and columns present in the DataFrame.

# %%
df.head()
# Out:
#    FIPS Code State         Area name  2003 Rural-urban Continuum Code  \
# 0       1007    AL       Bibb County                              1.0
# 1       1009    AL     Blount County                              1.0
# 2       1021    AL    Chilton County                              1.0
# 3       1073    AL  Jefferson County                              1.0
# 4       1115    AL  St. Clair County                              1.0
#
#    2003 Urban Influence Code  2013 Rural-urban Continuum Code  \
# 0                        1.0                              1.0
# 1                        1.0                              1.0
# 2                        1.0                              1.0
# 3                        1.0                              1.0
# 4                        1.0                              1.0
#
#    2013 Urban Influence Code City/Suburb/Town/Rural 2013  \
# 0                        1.0                        City
# 1                        1.0                        City
# 2                        1.0                        City
# 3                        1.0                        City
# 4                        1.0                        City
#
#   Less than a high school diploma, 1970 High school diploma only, 1970  ...  \
# 0                                 5,272                          1,402  ...
# 1                                10,677                          3,440  ...
# 2                                10,285                          2,805  ...
# 3                               186,882                        101,656  ...
# 4                                10,304                          3,540  ...
#
#   Percent of adults completing some college or associate's degree, 2000  \
# 0                                               20.4
# 1                                               24.8
# 2                                               20.5
# 3                                               28.4
# 4                                               25.6
#
#   Percent of adults with a bachelor's degree or higher, 2000  \
# 0                                                7.1
# 1                                                9.6
# 2                                                9.9
# 3                                               24.6
# 4                                               11.1
#
#    Less than a high school diploma, 2015-19  \
# 0                                     3,386
# 1                                     7,763
# 2                                     5,474
# 3                                    44,684
# 4                                     9,488
#
#    High school diploma only, 2015-19  \
# 0                              7,256
# 1                             13,299
# 2                             13,348
# 3                            118,636
# 4                             21,849
#
#    Some college or associate's degree, 2015-19  \
# 0                                        3,848
# 1                                       13,519
# 2                                        7,401
# 3                                      136,299
# 4                                       20,207
#
#    Bachelor's degree or higher, 2015-19  \
# 0                                 1,678
# 1                                 5,210
# 2                                 3,823
# 3                               150,124
# 4                                 9,880
#
#   Percent of adults with less than a high school diploma, 2015-19  \
# 0                                               20.9
# 1                                               19.5
# 2                                               18.2
# 3                                                9.9
# 4                                               15.4
#
#   Percent of adults with a high school diploma only, 2015-19  \
# 0                                               44.9
# 1                                               33.4
# 2                                               44.4
# 3                                               26.4
# 4                                               35.6
#
#   Percent of adults completing some college or associate's degree, 2015-19  \
# 0                                               23.8
# 1                                               34.0
# 2                                               24.6
# 3                                               30.3
# 4                                               32.9
#
#   Percent of adults with a bachelor's degree or higher, 2015-19
# 0                                               10.4
# 1                                               13.1
# 2                                               12.7
# 3                                               33.4
# 4                                               16.1
#
# [5 rows x 48 columns]

# %% [markdown]
# With the code below we'll have information such as the data types of each column: the name of each column, the number of non-null values in each column and the data type of each column. This makes it possible to understand the data.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3283 entries, 0 to 3282
# Data columns (total 48 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   FIPS Code                                                                 3283 non-null   int64
#  1   State                                                                     3283 non-null   object
#  2   Area name                                                                 3283 non-null   object
#  3   2003 Rural-urban Continuum Code                                           3221 non-null   float64
#  4   2003 Urban Influence Code                                                 3221 non-null   float64
#  5   2013 Rural-urban Continuum Code                                           3221 non-null   float64
#  6   2013 Urban Influence Code                                                 3221 non-null   float64
#  7   City/Suburb/Town/Rural 2013                                               3221 non-null   object
#  8   Less than a high school diploma, 1970                                     3186 non-null   object
#  9   High school diploma only, 1970                                            3186 non-null   object
#  10  Some college (1-3 years), 1970                                            3186 non-null   object
#  11  Four years of college or higher, 1970                                     3186 non-null   object
#  12  Percent of adults with less than a high school diploma, 1970              3186 non-null   float64
#  13  Percent of adults with a high school diploma only, 1970                   3186 non-null   float64
#  14  Percent of adults completing some college (1-3 years), 1970               3186 non-null   float64
#  15  Percent of adults completing four years of college or higher, 1970        3186 non-null   float64
#  16  Less than a high school diploma, 1980                                     3267 non-null   object
#  17  High school diploma only, 1980                                            3267 non-null   object
#  18  Some college (1-3 years), 1980                                            3267 non-null   object
#  19  Four years of college or higher, 1980                                     3267 non-null   object
#  20  Percent of adults with less than a high school diploma, 1980              3267 non-null   float64
#  21  Percent of adults with a high school diploma only, 1980                   3267 non-null   float64
#  22  Percent of adults completing some college (1-3 years), 1980               3267 non-null   float64
#  23  Percent of adults completing four years of college or higher, 1980        3267 non-null   float64
#  24  Less than a high school diploma, 1990                                     3271 non-null   object
#  25  High school diploma only, 1990                                            3271 non-null   object
#  26  Some college or associate's degree, 1990                                  3271 non-null   object
#  27  Bachelor's degree or higher, 1990                                         3271 non-null   object
#  28  Percent of adults with less than a high school diploma, 1990              3271 non-null   float64
#  29  Percent of adults with a high school diploma only, 1990                   3271 non-null   float64
#  30  Percent of adults completing some college or associate's degree, 1990     3270 non-null   float64
#  31  Percent of adults with a bachelor's degree or higher, 1990                3271 non-null   float64
#  32  Less than a high school diploma, 2000                                     3272 non-null   object
#  33  High school diploma only, 2000                                            3272 non-null   object
#  34  Some college or associate's degree, 2000                                  3272 non-null   object
#  35  Bachelor's degree or higher, 2000                                         3272 non-null   object
#  36  Percent of adults with less than a high school diploma, 2000              3272 non-null   float64
#  37  Percent of adults with a high school diploma only, 2000                   3272 non-null   float64
#  38  Percent of adults completing some college or associate's degree, 2000     3272 non-null   float64
#  39  Percent of adults with a bachelor's degree or higher, 2000                3272 non-null   float64
#  40  Less than a high school diploma, 2015-19                                  3273 non-null   object
#  41  High school diploma only, 2015-19                                         3273 non-null   object
#  42  Some college or associate's degree, 2015-19                               3273 non-null   object
#  43  Bachelor's degree or higher, 2015-19                                      3273 non-null   object
#  44  Percent of adults with less than a high school diploma, 2015-19           3273 non-null   float64
#  45  Percent of adults with a high school diploma only, 2015-19                3273 non-null   float64
#  46  Percent of adults completing some college or associate's degree, 2015-19  3273 non-null   float64
#  47  Percent of adults with a bachelor's degree or higher, 2015-19             3273 non-null   float64
# dtypes: float64(24), int64(1), object(23)
# memory usage: 1.2+ MB

# %% [markdown]
# Count of null values in each column of the df DataFrame, which can be useful for identifying areas of missing data that need to be dealt with before further analysis.

# %%
# Missing value
valores_faltantes = df.isnull().sum()

print(valores_faltantes)
# Out:
# FIPS Code                                                                    0
# State                                                                        0
# Area name                                                                    0
# 2003 Rural-urban Continuum Code                                             62
# 2003 Urban Influence Code                                                   62
# 2013 Rural-urban Continuum Code                                             62
# 2013 Urban Influence Code                                                   62
# City/Suburb/Town/Rural 2013                                                 62
# Less than a high school diploma, 1970                                       97
# High school diploma only, 1970                                              97
# Some college (1-3 years), 1970                                              97
# Four years of college or higher, 1970                                       97
# Percent of adults with less than a high school diploma, 1970                97
# Percent of adults with a high school diploma only, 1970                     97
# Percent of adults completing some college (1-3 years), 1970                 97
# Percent of adults completing four years of college or higher, 1970          97
# Less than a high school diploma, 1980                                       16
# High school diploma only, 1980                                              16
# Some college (1-3 years), 1980                                              16
# Four years of college or higher, 1980                                       16
# Percent of adults with less than a high school diploma, 1980                16
# Percent of adults with a high school diploma only, 1980                     16
# Percent of adults completing some college (1-3 years), 1980                 16
# Percent of adults completing four years of college or higher, 1980          16
# Less than a high school diploma, 1990                                       12
# High school diploma only, 1990                                              12
# Some college or associate's degree, 1990                                    12
# Bachelor's degree or higher, 1990                                           12
# Percent of adults with less than a high school diploma, 1990                12
# Percent of adults with a high school diploma only, 1990                     12
# Percent of adults completing some college or associate's degree, 1990       13
# Percent of adults with a bachelor's degree or higher, 1990                  12
# Less than a high school diploma, 2000                                       11
# High school diploma only, 2000                                              11
# Some college or associate's degree, 2000                                    11
# Bachelor's degree or higher, 2000                                           11
# Percent of adults with less than a high school diploma, 2000                11
# Percent of adults with a high school diploma only, 2000                     11
# Percent of adults completing some college or associate's degree, 2000       11
# Percent of adults with a bachelor's degree or higher, 2000                  11
# Less than a high school diploma, 2015-19                                    10
# High school diploma only, 2015-19                                           10
# Some college or associate's degree, 2015-19                                 10
# Bachelor's degree or higher, 2015-19                                        10
# Percent of adults with less than a high school diploma, 2015-19             10
# Percent of adults with a high school diploma only, 2015-19                  10
# Percent of adults completing some college or associate's degree, 2015-19    10
# Percent of adults with a bachelor's degree or higher, 2015-19               10
# dtype: int64

# %% [markdown]
#  This code was used to replace missing values when reading the dataframe and to convert values into integers, ensuring that null values are handled correctly.

# %%
missing_value_formats = ["n.a.","?","NA","n/a", "na", "--"]
df = pd.read_csv("education.csv", na_values = missing_value_formats)

def make_int(i):
    try:
        return int(i)
    except:
        return pd.np.nan

# %% [markdown]
# After executing the code, the missing values will be replaced by 0

# %%
df.fillna(0,inplace=True)

# %%
# Missing value
valores_faltantes = df.isnull().sum()

print(valores_faltantes)
# Out:
# FIPS Code                                                                   0
# State                                                                       0
# Area name                                                                   0
# 2003 Rural-urban Continuum Code                                             0
# 2003 Urban Influence Code                                                   0
# 2013 Rural-urban Continuum Code                                             0
# 2013 Urban Influence Code                                                   0
# City/Suburb/Town/Rural 2013                                                 0
# Less than a high school diploma, 1970                                       0
# High school diploma only, 1970                                              0
# Some college (1-3 years), 1970                                              0
# Four years of college or higher, 1970                                       0
# Percent of adults with less than a high school diploma, 1970                0
# Percent of adults with a high school diploma only, 1970                     0
# Percent of adults completing some college (1-3 years), 1970                 0
# Percent of adults completing four years of college or higher, 1970          0
# Less than a high school diploma, 1980                                       0
# High school diploma only, 1980                                              0
# Some college (1-3 years), 1980                                              0
# Four years of college or higher, 1980                                       0
# Percent of adults with less than a high school diploma, 1980                0
# Percent of adults with a high school diploma only, 1980                     0
# Percent of adults completing some college (1-3 years), 1980                 0
# Percent of adults completing four years of college or higher, 1980          0
# Less than a high school diploma, 1990                                       0
# High school diploma only, 1990                                              0
# Some college or associate's degree, 1990                                    0
# Bachelor's degree or higher, 1990                                           0
# Percent of adults with less than a high school diploma, 1990                0
# Percent of adults with a high school diploma only, 1990                     0
# Percent of adults completing some college or associate's degree, 1990       0
# Percent of adults with a bachelor's degree or higher, 1990                  0
# Less than a high school diploma, 2000                                       0
# High school diploma only, 2000                                              0
# Some college or associate's degree, 2000                                    0
# Bachelor's degree or higher, 2000                                           0
# Percent of adults with less than a high school diploma, 2000                0
# Percent of adults with a high school diploma only, 2000                     0
# Percent of adults completing some college or associate's degree, 2000       0
# Percent of adults with a bachelor's degree or higher, 2000                  0
# Less than a high school diploma, 2015-19                                    0
# High school diploma only, 2015-19                                           0
# Some college or associate's degree, 2015-19                                 0
# Bachelor's degree or higher, 2015-19                                        0
# Percent of adults with less than a high school diploma, 2015-19             0
# Percent of adults with a high school diploma only, 2015-19                  0
# Percent of adults completing some college or associate's degree, 2015-19    0
# Percent of adults with a bachelor's degree or higher, 2015-19               0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['FIPS Code', 'State', 'Area name', '2003 Rural-urban Continuum Code',
#        '2003 Urban Influence Code', '2013 Rural-urban Continuum Code',
#        '2013 Urban Influence Code', 'City/Suburb/Town/Rural 2013',
#        'Less than a high school diploma, 1970',
#        'High school diploma only, 1970', 'Some college (1-3 years), 1970',
#        'Four years of college or higher, 1970',
#        'Percent of adults with less than a high school diploma, 1970',
#        'Percent of adults with a high school diploma only, 1970',
#        'Percent of adults completing some college (1-3 years), 1970',
#        'Percent of adults completing four years of college or higher, 1970',
#        'Less than a high school diploma, 1980',
#        'High school diploma only, 1980', 'Some college (1-3 years), 1980',
#        'Four years of college or higher, 1980',
#        'Percent of adults with less than a high school diploma, 1980',
#        'Percent of adults with a high school diploma only, 1980',
#        'Percent of adults completing some college (1-3 years), 1980',
#        'Percent of adults completing four years of college or higher, 1980',
#        'Less than a high school diploma, 1990',
#        'High school diploma only, 1990',
#        'Some college or associate's degree, 1990',
#        'Bachelor's degree or higher, 1990',
#        'Percent of adults with less than a high school diploma, 1990',
#        'Percent of adults with a high school diploma only, 1990',
#        'Percent of adults completing some college or associate's degree, 1990',
#        'Percent of adults with a bachelor's degree or higher, 1990',
#        'Less than a high school diploma, 2000',
#        'High school diploma only, 2000',
#        'Some college or associate's degree, 2000',
#        'Bachelor's degree or higher, 2000',
#        'Percent of adults with less than a high school diploma, 2000',
#        'Percent of adults with a high school diploma only, 2000',
#        'Percent of adults completing some college or associate's degree, 2000',
#        'Percent of adults with a bachelor's degree or higher, 2000',
#        'Less than a high school diploma, 2015-19',
#        'High school diploma only, 2015-19',
#        'Some college or associate's degree, 2015-19',
#        'Bachelor's degree or higher, 2015-19',
#        'Percent of adults with less than a high school diploma, 2015-19',
#        'Percent of adults with a high school diploma only, 2015-19',
#        'Percent of adults completing some college or associate's degree, 2015-19',
#        'Percent of adults with a bachelor's degree or higher, 2015-19'],
#       dtype='object')

# %% [markdown]
# I decided to rename it just to make the name of each column smaller.

# %%
df = df.rename(columns={'Percent of adults with a high school diploma only, 1970': 'HSD 1970' })
df = df.rename(columns={'Percent of adults with less than a high school diploma, 2015-19': 'HSD 2015-19' })

# %%
df.head()
# Out:
#    FIPS Code State         Area name  2003 Rural-urban Continuum Code  \
# 0       1007    AL       Bibb County                              1.0
# 1       1009    AL     Blount County                              1.0
# 2       1021    AL    Chilton County                              1.0
# 3       1073    AL  Jefferson County                              1.0
# 4       1115    AL  St. Clair County                              1.0
#
#    2003 Urban Influence Code  2013 Rural-urban Continuum Code  \
# 0                        1.0                              1.0
# 1                        1.0                              1.0
# 2                        1.0                              1.0
# 3                        1.0                              1.0
# 4                        1.0                              1.0
#
#    2013 Urban Influence Code City/Suburb/Town/Rural 2013  \
# 0                        1.0                        City
# 1                        1.0                        City
# 2                        1.0                        City
# 3                        1.0                        City
# 4                        1.0                        City
#
#   Less than a high school diploma, 1970 High school diploma only, 1970  ...  \
# 0                                 5,272                          1,402  ...
# 1                                10,677                          3,440  ...
# 2                                10,285                          2,805  ...
# 3                               186,882                        101,656  ...
# 4                                10,304                          3,540  ...
#
#   Percent of adults completing some college or associate's degree, 2000  \
# 0                                               20.4
# 1                                               24.8
# 2                                               20.5
# 3                                               28.4
# 4                                               25.6
#
#   Percent of adults with a bachelor's degree or higher, 2000  \
# 0                                                7.1
# 1                                                9.6
# 2                                                9.9
# 3                                               24.6
# 4                                               11.1
#
#    Less than a high school diploma, 2015-19  \
# 0                                     3,386
# 1                                     7,763
# 2                                     5,474
# 3                                    44,684
# 4                                     9,488
#
#    High school diploma only, 2015-19  \
# 0                              7,256
# 1                             13,299
# 2                             13,348
# 3                            118,636
# 4                             21,849
#
#    Some college or associate's degree, 2015-19  \
# 0                                        3,848
# 1                                       13,519
# 2                                        7,401
# 3                                      136,299
# 4                                       20,207
#
#    Bachelor's degree or higher, 2015-19 HSD 2015-19  \
# 0                                 1,678        20.9
# 1                                 5,210        19.5
# 2                                 3,823        18.2
# 3                               150,124         9.9
# 4                                 9,880        15.4
#
#   Percent of adults with a high school diploma only, 2015-19  \
# 0                                               44.9
# 1                                               33.4
# 2                                               44.4
# 3                                               26.4
# 4                                               35.6
#
#   Percent of adults completing some college or associate's degree, 2015-19  \
# 0                                               23.8
# 1                                               34.0
# 2                                               24.6
# 3                                               30.3
# 4                                               32.9
#
#   Percent of adults with a bachelor's degree or higher, 2015-19
# 0                                               10.4
# 1                                               13.1
# 2                                               12.7
# 3                                               33.4
# 4                                               16.1
#
# [5 rows x 48 columns]

# %%
plt.scatter(df['HSD 1970'], df['HSD 2015-19'])
plt.xlabel('HSD 1970')
plt.ylabel('HSD 2015-19')
plt.title('Scatter Plot')
plt.show()

# %%
# Definindo cores com base nas coordenadas X e Y
cores = []
for index, row in df.iterrows():
    if row['HSD 1970'] > 3 and row['HSD 2015-19'] > 4:
        cores.append('red')
    else:
        cores.append('blue')
       

# Plotando os pontos com cores diferentes para X e Y
plt.scatter(df['HSD 1970'], df['HSD 2015-19'], c=cores)
plt.xlabel('HSD 1970')
plt.ylabel('HSD 2015-19')
plt.title('Scatter Plot com Cores Diferentes para X e Y')
plt.show()

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import pandas as pd

# Suponha que 'df' seja o seu DataFrame contendo os dados 'HSD 1970' e 'HSD 2015-19'

wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, max_iter=300, n_init=8, random_state=0)
    kmeans.fit(df[['HSD 1970', 'HSD 2015-19']])  # Use os dados reais do DataFrame
    wcss.append(kmeans.inertia_)

# Plotar o método do cotovelo
plt.plot(range(1, 11), wcss)
plt.title('Elbow Graph')
plt.xlabel('HSD 1970')
plt.ylabel('HSD 2015-19')  # Within cluster sum of squares
plt.show()

# %%
from sklearn.cluster import KMeans
import pandas as pd

# Suponha que 'df' seja o seu DataFrame contendo os dados 'HSD 1970' e 'HSD 2015-19'

# Inicializar o modelo KMeans com o número desejado de clusters
kmeans = KMeans(n_clusters=3, max_iter=300, n_init=8, random_state=0)

# Ajustar o modelo aos seus dados
kmeans.fit(df[['HSD 1970', 'HSD 2015-19']])

# Obter as previsões dos clusters para os seus dados
y_predicted = kmeans.predict(df[['HSD 1970', 'HSD 2015-19']])

# Exibir as previsões
print(y_predicted)
# Out:
# [0 0 0 ... 2 2 1]

# %%
df['cluster'] = y_predicted
df.head()
# Out:
#    FIPS Code State         Area name  2003 Rural-urban Continuum Code  \
# 0       1007    AL       Bibb County                              1.0
# 1       1009    AL     Blount County                              1.0
# 2       1021    AL    Chilton County                              1.0
# 3       1073    AL  Jefferson County                              1.0
# 4       1115    AL  St. Clair County                              1.0
#
#    2003 Urban Influence Code  2013 Rural-urban Continuum Code  \
# 0                        1.0                              1.0
# 1                        1.0                              1.0
# 2                        1.0                              1.0
# 3                        1.0                              1.0
# 4                        1.0                              1.0
#
#    2013 Urban Influence Code City/Suburb/Town/Rural 2013  \
# 0                        1.0                        City
# 1                        1.0                        City
# 2                        1.0                        City
# 3                        1.0                        City
# 4                        1.0                        City
#
#   Less than a high school diploma, 1970 High school diploma only, 1970  ...  \
# 0                                 5,272                          1,402  ...
# 1                                10,677                          3,440  ...
# 2                                10,285                          2,805  ...
# 3                               186,882                        101,656  ...
# 4                                10,304                          3,540  ...
#
#   Percent of adults with a bachelor's degree or higher, 2000  \
# 0                                                7.1
# 1                                                9.6
# 2                                                9.9
# 3                                               24.6
# 4                                               11.1
#
#   Less than a high school diploma, 2015-19  High school diploma only, 2015-19  \
# 0                                    3,386                              7,256
# 1                                    7,763                             13,299
# 2                                    5,474                             13,348
# 3                                   44,684                            118,636
# 4                                    9,488                             21,849
#
#    Some college or associate's degree, 2015-19  \
# 0                                        3,848
# 1                                       13,519
# 2                                        7,401
# 3                                      136,299
# 4                                       20,207
#
#    Bachelor's degree or higher, 2015-19  HSD 2015-19  \
# 0                                 1,678         20.9
# 1                                 5,210         19.5
# 2                                 3,823         18.2
# 3                               150,124          9.9
# 4                                 9,880         15.4
#
#   Percent of adults with a high school diploma only, 2015-19  \
# 0                                               44.9
# 1                                               33.4
# 2                                               44.4
# 3                                               26.4
# 4                                               35.6
#
#   Percent of adults completing some college or associate's degree, 2015-19  \
# 0                                               23.8
# 1                                               34.0
# 2                                               24.6
# 3                                               30.3
# 4                                               32.9
#
#   Percent of adults with a bachelor's degree or higher, 2015-19 cluster
# 0                                               10.4                  0
# 1                                               13.1                  0
# 2                                               12.7                  0
# 3                                               33.4                  2
# 4                                               16.1                  0
#
# [5 rows x 49 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn_extra.cluster import KMedoids
from sklearn.metrics import silhouette_samples, silhouette_score

# Suponha que 'df' seja o seu DataFrame contendo os dados

# Store 'HSD 2015-19' and 'HSD 1970' from 'df'
D = df[['HSD 2015-19', 'HSD 1970']].values

# Initialise the range of clusters
cluster_range = range(2, 11)

# Store silhouette scores
silhouette_scores = []

# Iterate over cluster range
for num_clusters in cluster_range:
    # Apply KMedoids
    kmedoids = KMedoids(n_clusters=num_clusters, random_state=0)
    clusters = kmedoids.fit_predict(D)
    
    # Compute silhouette score
    silhouette_avg = silhouette_score(D, clusters)
    silhouette_scores.append(silhouette_avg)

    # Compute silhouette coefficients
    sample_silhouette_values = silhouette_samples(D, clusters)

    # Plot
    fig, ax = plt.subplots()
    y_lower = 10
    
    for i in range(num_clusters):
        # Aggregate the silhouette scores for samples belonging to cluster i, and sort them
        ith_cluster_silhouette_values = sample_silhouette_values[clusters == i]
        ith_cluster_silhouette_values.sort()

        # Get the size of each cluster
        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        # Color the clusters
        color = plt.cm.viridis(float(i) / num_clusters)
        ax.fill_betweenx(np.arange(y_lower, y_upper), 0, ith_cluster_silhouette_values, facecolor=color, edgecolor=color, alpha=0.7)

        # Label the silhouette plots with their cluster numbers at the middle
        ax.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for the next plot
        y_lower = y_upper + 10

    ax.set_title("Silhouette plot for {} clusters".format(num_clusters))
    ax.set_xlabel("Silhouette coefficient values")
    ax.set_ylabel("Cluster label")
    ax.axvline(x=silhouette_avg, color="red", linestyle="--")
    ax.set_yticks([])  # Clear the y-axis labels
    ax.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])
    plt.show()

# Plot the silhouette scores vs. number of clusters
plt.figure(figsize=(8, 6))
plt.plot(cluster_range, silhouette_scores, marker='o', linestyle='-')
plt.title('Silhouette Score vs. Number of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('Silhouette Score')
plt.grid(True)
plt.show()

# %%
# Boxplot para cada coluna
plt.figure(figsize=(10, 6))
sns.boxplot(data=df)
plt.title('Boxplot para Identificação de Outliers')
plt.xticks(rotation=45)
plt.show()

# %%
# Scatterplot entre duas colunas
plt.figure(figsize=(8, 6))
plt.scatter(df['HSD 1970'], df['HSD 2015-19'])
plt.title('Scatterplot para Identificação de Outliers')
plt.xlabel('HSD 1970')
plt.ylabel('HSD 2015-19')
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Suponha que 'df' seja o seu DataFrame contendo os dados

# Boxplot para as duas colunas
plt.figure(figsize=(10, 6))
sns.boxplot(data=df[['HSD 1970', 'HSD 2015-19']])
plt.title('Boxplot para Duas Colunas')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # k -means

# %%
# Definir X e y
X = df['HSD 1970']
y = df['HSD 2015-19']  # Recursos

# %%
#Import k-means
from sklearn.cluster import KMeans

# %%
# Converter a Series para um array NumPy e remodelar para duas dimensões
X_array = X.values.reshape(-1, 1)

# %%
# Algoritmo KMeans com 6 clusters
kmeans = KMeans(n_clusters=3, random_state=0).fit(X_array)

# %%
kmeans.labels_
# Out:
# array([0, 0, 0, ..., 1, 1, 2])

# %%
fig, ax = plt.subplots()

ax.scatter(X_array, y, c=kmeans.labels_)

plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import pandas as pd

# Suponha que 'df' seja o seu DataFrame contendo os dados 'HSD 1970' e 'HSD 2015-19'

# Inicializar o modelo KMeans com o número desejado de clusters
kmeans = KMeans(n_clusters=5, max_iter=300, n_init=8, random_state=0)

# Ajustar o modelo aos seus dados
kmeans.fit(df[['HSD 1970', 'HSD 2015-19']])

# Obter as previsões dos clusters para os seus dados
y_predicted = kmeans.predict(df[['HSD 1970', 'HSD 2015-19']])

# Adicionar as previsões dos clusters como uma nova coluna em 'df'
df['Cluster'] = y_predicted

# Plotar o gráfico de dispersão com os clusters
plt.figure(figsize=(8, 6))
plt.scatter(df['HSD 1970'], df['HSD 2015-19'], c=df['Cluster'], cmap='viridis', alpha=0.5)
plt.title('Clustering K-means dos Dados HSD 1970 e HSD 2015-19')
plt.xlabel('HSD 1970')
plt.ylabel('HSD 2015-19')
plt.colorbar(label='Cluster')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import pandas as pd

# Suponha que 'df' seja o seu DataFrame contendo os dados 'HSD 1970' e 'HSD 2015-19'

# Inicializar o modelo KMeans com o número desejado de clusters
kmeans = KMeans(n_clusters=6, max_iter=300, n_init=8, random_state=0)

# Ajustar o modelo aos seus dados
kmeans.fit(df[['HSD 1970', 'HSD 2015-19']])

# Obter as previsões dos clusters para os seus dados
y_predicted = kmeans.predict(df[['HSD 1970', 'HSD 2015-19']])

# Adicionar as previsões dos clusters como uma nova coluna em 'df'
df['Cluster'] = y_predicted

# Plotar o gráfico de dispersão com os clusters
plt.figure(figsize=(8, 6))
plt.scatter(df['HSD 1970'], df['HSD 2015-19'], c=df['Cluster'], cmap='viridis', alpha=0.5)
plt.title('Clustering K-means dos Dados HSD 1970 e HSD 2015-19')
plt.xlabel('HSD 1970')
plt.ylabel('HSD 2015-19')

# Adicionar os centróides
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='red', marker='X', label='Centroids')

plt.colorbar(label='Cluster')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Definir X e y
X = df['HSD 1970']
y = df['HSD 2015-19']  # Recursos

# %% [markdown]
# # Clustering KMedoid

# %%
# Install the scikit-learn-extra library before the execution of next cell
# !pip install scikit-learn-extra
# Out:
# Requirement already satisfied: scikit-learn-extra in c:\users\karik\anaconda3\lib\site-packages (0.3.0)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\karik\anaconda3\lib\site-packages (from scikit-learn-extra) (1.24.3)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\karik\anaconda3\lib\site-packages (from scikit-learn-extra) (1.10.1)
# Requirement already satisfied: scikit-learn>=0.23.0 in c:\users\karik\anaconda3\lib\site-packages (from scikit-learn-extra) (1.3.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\karik\anaconda3\lib\site-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\karik\anaconda3\lib\site-packages (from scikit-learn>=0.23.0->scikit-learn-extra) (2.2.0)

# %%
# Store 'HSD 2015-19' and 'HSD 1970' from 'df'
D = df[['HSD 2015-19', 'HSD 1970']].values

# Initialise the number of clusters
cluster_num = 6

# Apply KMedoids
kmedoids = KMedoids(n_clusters=cluster_num, random_state=0)
clusters = kmedoids.fit_predict(D)

# Plot
plt.figure(figsize=(8, 6))
plt.scatter(D[:, 0], D[:, 1], c=clusters, cmap='viridis', alpha=0.5)
plt.title('Clustering K-Medoids dos Dados HSD 1970 e HSD 2015-19')
plt.xlabel('HSD 1970')
plt.ylabel('HSD 2015-19')
plt.grid(True)
plt.colorbar(label='Cluster')
plt.show()

# %%
# Display the attributes Petal length and Petal width
print(D)
# Out:
# [[20.9 19.4]
#  [19.5 22.7]
#  [18.2 20. ]
#  ...
#  [ 7.8 34.8]
#  [ 6.8 36.2]
#  [23.5  0. ]]

# %% [markdown]
# # Stock marketing data
#  DBEREL02 - Household Electricity Consumption

# %%
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from statsmodels.tsa.stattools import adfuller
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook
import numpy as np
import pandas as pd

from itertools import product
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.metrics import median_absolute_error, mean_squared_log_error

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
data = pd.read_csv('DBEREL02.20240421124714.csv')

# %%
data.head()
# Out:
#      STATISTIC                    Statistic Label  TLIST(A1)  Year  \
# 0  DBEREL02C01  Household Electricity Consumption       2015  2015
# 1  DBEREL02C01  Household Electricity Consumption       2015  2015
# 2  DBEREL02C01  Household Electricity Consumption       2015  2015
# 3  DBEREL02C01  Household Electricity Consumption       2015  2015
# 4  DBEREL02C01  Household Electricity Consumption       2015  2015
#
#   C03151V03803 Type of Dwelling C03441V04150     Period of Construction  \
# 0           01        Apartment          011                  1900-1966
# 1           01        Apartment          091                  1967-1999
# 2           01        Apartment           03                  2000-2004
# 3           01        Apartment          113                  2005-2022
# 4           01        Apartment            -  All years of construction
#
#                   UNIT   VALUE
# 0  Mean kilowatt-hours  3552.0
# 1  Mean kilowatt-hours  4822.0
# 2  Mean kilowatt-hours  5473.0
# 3  Mean kilowatt-hours  5328.0
# 4  Mean kilowatt-hours  5057.0

# %%
# Number of rows
num_rows = data.shape[0]

# Number of columns
num_columns = data.shape[1]

print("Number of rows:", num_rows)
print("Number of columns:", num_columns)
# Out:
# Number of rows: 240
# Number of columns: 10

# %%
data = data.drop(columns=['STATISTIC'])

# %% [markdown]
# # Data visualization

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.boxplot(data=data, x='Period of Construction', y='VALUE')
ax.set_title('Household Electricity Consumption')
plt.show()

# %%
# Plote o gráfico de dispersão
plt.figure(figsize=[10, 6])  # Defina o tamanho da figura
plt.scatter(data['Period of Construction'], data['VALUE'], color='b', alpha=0.7)  # Gráfico de dispersão

# Adicione título e rótulos aos eixos
plt.title('Household Electricity Consumption', fontsize=16)
plt.ylabel('Mean kilowatt-hours', fontsize=12)
plt.xlabel('Year', fontsize=12)

# Rotacione os rótulos do eixo x em 45 graus
plt.xticks(rotation=45)

# Adicione grades para facilitar a leitura
plt.grid(True)

# Exiba o gráfico
plt.show()

# %%
# Household Electricity Consumption
plt.figure(figsize=[12, 5]); # Set dimensions for figure
data.plot(x = 'Period of Construction', y = 'VALUE', figsize = (14, 6), color = 'b')   # 
plt.title('Household Electricity Consumption')
plt.ylabel('Mean kilowatt-hours')
plt.xlabel('Year')
plt.xticks(rotation = 50)
plt.grid(True)
plt.show()

# %%
# Plote o gráfico de linha
plt.plot(data['Period of Construction'], data['VALUE'], color='b')

# Adicione título e rótulos aos eixos
plt.title('Household Electricity Consumption')
plt.ylabel('Mean kilowatt-hours)')
plt.xlabel('Year')

# Rotacione os rótulos do eixo x para melhor legibilidade
plt.xticks(rotation=90)

# Adicione grades para facilitar a leitura
plt.grid(True)

# Exiba o gráfico
plt.show()

# %%
# Classifique os dados pelo ano
data_sorted = data.sort_values(by='Year')

# Ajuste as dimensões da figura
plt.figure(figsize=[12, 5])

# Plote o gráfico de linha conectando os pontos
plt.plot(data_sorted['Period of Construction'], data_sorted['VALUE'], color='b', marker='o', linestyle='-')

# Adicione título e rótulos aos eixos
plt.title('Net Electricity Generation from Coal since 1973')
plt.ylabel('Net Electricity Generation (kWh)')
plt.xlabel('Year')

# Rotacione os rótulos do eixo x para melhor legibilidade
plt.xticks(rotation=90)

# Adicione grades para facilitar a leitura
plt.grid(True)

# Exiba o gráfico
plt.show()

# %%
# Ajuste as dimensões da figura
plt.figure(figsize=[12, 5])

# Plote o gráfico de linha interligado
plt.plot(data['Period of Construction'], data['VALUE'], color='b', marker='o', linestyle='-')

# Adicione título e rótulos aos eixos
plt.title('Net Electricity Generation from Coal since 1973')
plt.ylabel('Net Electricity Generation (kWh)')
plt.xlabel('Year')

# Rotacione os rótulos do eixo x para melhor legibilidade
plt.xticks(rotation=90)

# Adicione grades para facilitar a leitura
plt.grid(True)

# Exiba o gráfico
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller

# Remover linhas com valores ausentes
data_cleaned = data.dropna()

# Substituir valores infinitos por NaNs e, em seguida, remover linhas com NaNs
data_cleaned.replace([np.inf, -np.inf], np.nan, inplace=True)
data_cleaned.dropna(inplace=True)

# Realizar o teste ADF nos dados limpos
ad_fuller_result = adfuller(data_cleaned['VALUE'])

# Exibir o resultado do teste ADF
print(f'ADF Statistic: {ad_fuller_result[0]}')
# Out:
# ADF Statistic: -5.468059116505677

# %%
data['Electricity First Difference'] = data['VALUE'] - data['VALUE'].shift(1)
# Shift index by desired number of periods with an optional time `freq`.

# Show first five records
data.head()
# Out:
#                      Statistic Label  TLIST(A1)  Year C03151V03803  \
# 0  Household Electricity Consumption       2015  2015           01
# 1  Household Electricity Consumption       2015  2015           01
# 2  Household Electricity Consumption       2015  2015           01
# 3  Household Electricity Consumption       2015  2015           01
# 4  Household Electricity Consumption       2015  2015           01
#
#   Type of Dwelling C03441V04150     Period of Construction  \
# 0        Apartment          011                  1900-1966
# 1        Apartment          091                  1967-1999
# 2        Apartment           03                  2000-2004
# 3        Apartment          113                  2005-2022
# 4        Apartment            -  All years of construction
#
#                   UNIT   VALUE  Electricity First Difference
# 0  Mean kilowatt-hours  3552.0                           NaN
# 1  Mean kilowatt-hours  4822.0                        1270.0
# 2  Mean kilowatt-hours  5473.0                         651.0
# 3  Mean kilowatt-hours  5328.0                        -145.0
# 4  Mean kilowatt-hours  5057.0                        -271.0

# %%
# Drop NA values
data.dropna(subset = ["Electricity First Difference"], inplace = True)

# Show first five records
data.head()
# Out:
#                      Statistic Label  TLIST(A1)  Year C03151V03803  \
# 1  Household Electricity Consumption       2015  2015           01
# 2  Household Electricity Consumption       2015  2015           01
# 3  Household Electricity Consumption       2015  2015           01
# 4  Household Electricity Consumption       2015  2015           01
# 5  Household Electricity Consumption       2015  2015           11
#
#     Type of Dwelling C03441V04150     Period of Construction  \
# 1          Apartment          091                  1967-1999
# 2          Apartment           03                  2000-2004
# 3          Apartment          113                  2005-2022
# 4          Apartment            -  All years of construction
# 5  Mid-terrace house          011                  1900-1966
#
#                   UNIT   VALUE  Electricity First Difference
# 1  Mean kilowatt-hours  4822.0                        1270.0
# 2  Mean kilowatt-hours  5473.0                         651.0
# 3  Mean kilowatt-hours  5328.0                        -145.0
# 4  Mean kilowatt-hours  5057.0                        -271.0
# 5  Mean kilowatt-hours  4036.0                       -1021.0

# %%
# Augmented Dickey-Fuller test
ad_fuller_result = adfuller(data['Electricity First Difference'])

# Display the outcomes of Dicky Fuller test
print(f'ADF Statistic: {ad_fuller_result[0]}')
print(f'p-value: {ad_fuller_result[1]}')
# Out:
# ADF Statistic: -5.784278246755235
# p-value: 5.041737485831914e-07

# %%
plt.figure(figsize = [12, 5]); # Set dimensions for figure
data['Electricity First Difference'].plot()
plt.title('Household Electricity Consumption')
plt.ylabel('Mean kilowatt-hours')
plt.grid(True)

# %%
import statsmodels.api as sm
fig = plt.figure(figsize = (14, 6))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(data['Electricity First Difference'].dropna(),lags = 40,ax = ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(data['Electricity First Difference'].dropna(),lags = 40,ax = ax2)

# %%
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.arima.model import ARIMA
# A nested loop is written to calculate the AIC values
aicVal=[]
for d in range(1,3):
    for ari in range(0, 3):
        for maj in range(0,3):
            try:
                arima_obj = ARIMA(data['VALUE'], order=(ari,d,maj))
                arima_obj_fit=arima_obj.fit()
                aicVal.append([ari, d, maj, arima_obj_fit.aic])
            except ValueError:
                pass
print(aicVal)
# Out:
# [[0, 1, 0, 3710.2101438961627], [0, 1, 1, 3711.536513148177], [0, 1, 2, 3675.327614130082], [1, 1, 0, 3711.83898105205], [1, 1, 1, 3712.281033095714], [1, 1, 2, 3657.626746453122], [2, 1, 0, 3698.5009599921673], [2, 1, 1, 3652.971405264409], [2, 1, 2, 3654.9701301057544], [0, 2, 0, 3840.422666379501], [0, 2, 1, 3705.562793500557], [0, 2, 2, 3706.3136490204106], [1, 2, 0, 3815.0120512435033], [1, 2, 1, 3706.873037204613], [1, 2, 2, 3707.0165502148902], [2, 2, 0, 3800.3887923791945], [2, 2, 1, 3693.5463070423075], [2, 2, 2, 3706.651329812256]]

# %% [markdown]
# # SARIMA Mode

# %%
# order = (2, 1, 2) means 
# First 2 for auto regressive model, 1 for difference, and second 2 for moving average
# seasonal_order = (2, 1, 2, 12) means
# 12 additional parameter means number of observations per year or the period
best_model = SARIMAX(data['VALUE'], order = (2, 1, 2), seasonal_order = (2, 1, 2, 12)).fit(dis = -1)

# Display the summary of the model
print(best_model.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              VALUE   No. Observations:                  224
# Model:             SARIMAX(2, 1, 2)x(2, 1, 2, 12)   Log Likelihood               -1751.204
# Date:                            Wed, 24 Apr 2024   AIC                           3520.408
# Time:                                    13:47:47   BIC                           3550.575
# Sample:                                         0   HQIC                          3532.602
#                                             - 224
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8569      0.017     51.372      0.000       0.824       0.890
# ar.L2         -0.9960      0.023    -42.504      0.000      -1.042      -0.950
# ma.L1         -0.8200      0.098     -8.327      0.000      -1.013      -0.627
# ma.L2          0.9709      0.122      7.953      0.000       0.732       1.210
# ar.S.L12      -0.3317      0.662     -0.501      0.616      -1.629       0.966
# ar.S.L24      -0.3685      0.227     -1.626      0.104      -0.813       0.076
# ma.S.L12      -0.8124      0.696     -1.167      0.243      -2.177       0.552
# ma.S.L24       0.0757      0.672      0.113      0.910      -1.242       1.394
# sigma2      1.645e+06   4.01e-07    4.1e+12      0.000    1.64e+06    1.64e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.34   Jarque-Bera (JB):                11.33
# Prob(Q):                              0.56   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.82   Skew:                            -0.44
# Prob(H) (two-sided):                  0.40   Kurtosis:                         3.73
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 8.96e+28. Standard errors may be unstable.

# %%
# Diagnosing the model residuals
best_model.plot_diagnostics(figsize = (15, 12))
plt.show()

# %% [markdown]
# # Model Forecast

# %%
# Forecasting 3 years steps ahead
forecast_values = best_model.get_forecast(steps = 120)

# Confidence intervals of the forecasted values
forecast_ci = forecast_values.conf_int()

# Plot the data
ax = data.plot(x = 'Period of Construction', y = 'VALUE', figsize = (14, 6), legend = True, color = 'purple')

# Plot the forecasted values 
forecast_values.predicted_mean.plot(ax = ax, label = 'Forecast', figsize = (16, 8), grid = True)

# Plot the confidence intervals
ax.fill_between(forecast_ci.index,
                forecast_ci.iloc[: , 0],
                forecast_ci.iloc[: , 1], color = 'yellow', alpha = .5)
plt.title('Household Electricity Consumption', size = 16)
plt.ylabel('KWh', size = 12)
plt.legend(loc = 'upper left', prop = {'size': 12})
ax.axes.get_xaxis().set_visible(True)
# annotation
ax.text(540, 400, 'Forecasted Values Until 2030', fontsize = 12,  color = 'red')
plt.show()

# %%
# Divide into train and validation set to calculate R-squared score and mean absolute percentage error 
train = data[:int(0.85 * (len(data)))]
test  = data[int(0.85 * (len(data))):]

train.shape, test.shape
# Out:
# ((190, 10), (34, 10))

# %%
train.head()
# Out:
#                      Statistic Label  TLIST(A1)  Year C03151V03803  \
# 1  Household Electricity Consumption       2015  2015           01
# 2  Household Electricity Consumption       2015  2015           01
# 3  Household Electricity Consumption       2015  2015           01
# 4  Household Electricity Consumption       2015  2015           01
# 5  Household Electricity Consumption       2015  2015           11
#
#     Type of Dwelling C03441V04150     Period of Construction  \
# 1          Apartment          091                  1967-1999
# 2          Apartment           03                  2000-2004
# 3          Apartment          113                  2005-2022
# 4          Apartment            -  All years of construction
# 5  Mid-terrace house          011                  1900-1966
#
#                   UNIT   VALUE  Electricity First Difference
# 1  Mean kilowatt-hours  4822.0                        1270.0
# 2  Mean kilowatt-hours  5473.0                         651.0
# 3  Mean kilowatt-hours  5328.0                        -145.0
# 4  Mean kilowatt-hours  5057.0                        -271.0
# 5  Mean kilowatt-hours  4036.0                       -1021.0

# %%
start = len(train)
end   = len(train) + len(test) - 1

print(start, end)
# Out:
# 190 223

# %%
start = len(train)
end   = len(train) + len(test) - 1
predictions = best_model.predict(start = start, end = end, dynamic = False, typ = 'levels').rename('SARIMA Predictions')
print(predictions)
# Out:
# 203    9471.673376
# 204    7648.921015
# 205    7128.281726
# 206    5286.737512
# 207    6114.309454
# 208    6330.194805
# 211    5253.966688
# 212    4829.171927
# 213    4879.844095
# 214    4351.528871
# 215    3642.222656
# 216    4658.511508
# 217    4708.202096
# 218    4318.108209
# 219    3609.644861
# 220    5482.622449
# 221    4855.347668
# 222    4690.338151
# 223    4278.610964
# 224    4579.220099
# 225    4994.308933
# 226    5200.948029
# 227    4014.408258
# 228    4978.898478
# 229    4020.744202
# 230    4458.954534
# 231    5361.280012
# 232    7656.259427
# 233    8691.900392
# 234    6859.936145
# 235    6572.965953
# 236    4945.782121
# 237    5733.964215
# 238    5914.730012
# Name: SARIMA Predictions, dtype: float64

# %%
# Create a dataframe to store r2 score
evaluation_results = pd.DataFrame({'r2_score': r2_score(test['Year'], predictions)}, index = [0])

# Add columns in the dataframe 'evaluation_results'
evaluation_results['mean_absolute_error'] = mean_absolute_error(test['Year'], predictions)
evaluation_results['mean_squared_error'] = mean_squared_error(test['Year'], predictions)
evaluation_results['root_mean_squared_error'] = np.sqrt(mean_squared_error(test['Year'], predictions))
evaluation_results['mean_absolute_percentage_error'] = np.mean(np.abs(predictions - test['Year'])
                                                               /np.abs(test['Year']))*100 
# Display the results
evaluation_results
# Out:
#        r2_score  mean_absolute_error  mean_squared_error  \
# 0 -9.412483e+07          3434.721731        1.367904e+07
#
#    root_mean_squared_error  mean_absolute_percentage_error
# 0               3698.51882                      169.889031
